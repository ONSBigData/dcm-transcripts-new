# %%
import numpy as np
from sklearn import preprocessing
import python_speech_features as mfcc

import pandas as pd

import numpy as np
from scipy.io.wavfile import read
from sklearn.mixture import GMM 

import warnings
warnings.filterwarnings("ignore")

import six
from six.moves import cPickle as pickle

# %%
def calculate_delta(array):
    """Calculate and returns the delta of given feature vector matrix"""

    rows,cols = array.shape
    deltas = np.zeros((rows,20))
    N = 2
    for i in range(rows):
        index = []
        j = 1
        while j <= N:
            if i-j < 0:
                first = 0
            else:
                first = i-j
            if i+j > rows -1:
                second = rows -1
            else:
                second = i+j
            index.append((second,first))
            j+=1
        deltas[i] = ( array[index[0][0]]-array[index[0][1]] + (2 * (array[index[1][0]]-array[index[1][1]])) ) / 10
    return deltas

def extract_features(audio,rate):
    """extract 20 dim mfcc features from an audio, performs CMS and combines 
    delta to make it 40 dim feature vector"""    
    
    mfcc_feat = mfcc.mfcc(audio,rate, 0.025, 0.01,20,appendEnergy = True)
    
    mfcc_feat = preprocessing.scale(mfcc_feat)
    delta = calculate_delta(mfcc_feat)
    combined = np.hstack((mfcc_feat,delta)) 
    return combined

# %%
##/home/bigdata/scripts/DCMWork/development_set/

#path to training data
source   = "/home/bigdata/scripts/development_set/"   

#path where training speakers will be saved
dest = "speaker_models/"

# %%
source.strip()
dest.strip()
# Out:
# 'speaker_models/'

# %%
##/home/bigdata/scripts/DCMWork/development_set/

#path to training data
source   = "/home/bigdata/scripts/development_set/"   

#path where training speakers will be saved
dest = "speaker_models/"

train_file = "development_set_enroll.txt"        


file_paths = open(train_file,'r')


file_pd = pd.read_csv(train_file,sep="%",header=None)
file_pd=file_pd.rename( columns={0: "fpath"})

file_pd
# Out:
#                                        fpath
# 0    anthonyschaller-20071221-\wav\a0491.wav
# 1    anthonyschaller-20071221-\wav\a0492.wav
# 2    anthonyschaller-20071221-\wav\a0493.wav
# 3    anthonyschaller-20071221-\wav\a0494.wav
# 4    anthonyschaller-20071221-\wav\a0495.wav
# 5     Apple_Eater-20091026-yul\wav\a0052.wav
# 6     Apple_Eater-20091026-yul\wav\a0053.wav
# 7     Apple_Eater-20091026-yul\wav\a0054.wav
# 8     Apple_Eater-20091026-yul\wav\a0055.wav
# 9     Apple_Eater-20091026-yul\wav\a0056.wav
# 10            Ara-20091020-vni\wav\a0517.wav
# 11            Ara-20091020-vni\wav\a0518.wav
# 12            Ara-20091020-vni\wav\a0519.wav
# 13            Ara-20091020-vni\wav\a0520.wav
# 14            Ara-20091020-vni\wav\a0521.wav
# 15         argail-20090722-gau\wav\rb-12.wav
# 16         argail-20090722-gau\wav\rb-13.wav
# 17         argail-20090722-gau\wav\rb-14.wav
# 18         argail-20090722-gau\wav\rb-15.wav
# 19         argail-20090722-gau\wav\rb-16.wav
# 20         ariyan-20120801-gra\wav\b0265.wav
# 21         ariyan-20120801-gra\wav\b0266.wav
# 22         ariyan-20120801-gra\wav\b0267.wav
# 23         ariyan-20120801-gra\wav\b0268.wav
# 24         ariyan-20120801-gra\wav\b0269.wav
# 25         arjuan-20100820-acz\wav\b0217.wav
# 26         arjuan-20100820-acz\wav\b0218.wav
# 27         arjuan-20100820-acz\wav\b0219.wav
# 28         arjuan-20100820-acz\wav\b0220.wav
# 29         arjuan-20100820-acz\wav\b0221.wav
# ..                                       ...
# 140      Bareford-20101110-qkl\wav\a0012.wav
# 141      Bareford-20101110-qkl\wav\a0013.wav
# 142      Bareford-20101110-qkl\wav\a0014.wav
# 143      Bareford-20101110-qkl\wav\a0015.wav
# 144      Bareford-20101110-qkl\wav\a0016.wav
# 145          bart-20090807-ufp\wav\b0421.wav
# 146          bart-20090807-ufp\wav\b0422.wav
# 147          bart-20090807-ufp\wav\b0423.wav
# 148          bart-20090807-ufp\wav\b0424.wav
# 149          bart-20090807-ufp\wav\b0425.wav
# 150        Bassel-20120209-xky\wav\b0425.wav
# 151        Bassel-20120209-xky\wav\b0426.wav
# 152        Bassel-20120209-xky\wav\b0427.wav
# 153        Bassel-20120209-xky\wav\b0428.wav
# 154        Bassel-20120209-xky\wav\b0429.wav
# 155         beady-20100219-xpq\wav\a0441.wav
# 156         beady-20100219-xpq\wav\a0442.wav
# 157         beady-20100219-xpq\wav\a0443.wav
# 158         beady-20100219-xpq\wav\a0444.wav
# 159         beady-20100219-xpq\wav\a0445.wav
# 160      beez1717-20111017-yqm\wav\a0081.wav
# 161      beez1717-20111017-yqm\wav\a0082.wav
# 162      beez1717-20111017-yqm\wav\a0083.wav
# 163      beez1717-20111017-yqm\wav\a0084.wav
# 164      beez1717-20111017-yqm\wav\a0085.wav
# 165    belmontguy-20110426-geu\wav\b0149.wav
# 166    belmontguy-20110426-geu\wav\b0150.wav
# 167    belmontguy-20110426-geu\wav\b0151.wav
# 168    belmontguy-20110426-geu\wav\b0152.wav
# 169    belmontguy-20110426-geu\wav\b0153.wav
#
# [170 rows x 1 columns]

# %%
count = 1

# Extracting features for each speaker (5 files per speakers)
features = np.asarray(())
for path in file_paths:    
    stipedpath = source.strip() + path.strip()   
    print (stipedpath)
    
    # read the audio
    sr,audio = read(stipedpath)
    
    # extract 40 dimensional MFCC & delta MFCC features
    vector   = extract_features(audio,sr)
    
    if features.size == 0:
        features = vector
    else:
        features = np.vstack((features, vector))
    # when features of 5 files of speaker are concatenated, then do model training
    if count == 5:    
        gmm = GMM(n_components = 16, n_iter = 200, covariance_type='diag',n_init = 3)
        gmm.fit(features)
        
        # dumping the trained gaussian model
        picklefile = path.split("-")[0]+".gmm"
        cPickle.dump(gmm,open(dest + picklefile,'w'))
        print ('+ modeling completed for speaker:',picklefile," with data point = ",features.shape)    
        features = np.asarray(())
        count = 0
    count = count + 1
# Out:
# /home/bigdata/scripts/development_set/anthonyschaller-20071221-\wav\a0491.wav
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-a6e0f4d7accc> in <module>()
#      24
#      25     # read the audio
# ---> 26     sr,audio = read(stipedpath)
#      27
#      28     # extract 40 dimensional MFCC & delta MFCC features
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/io/wavfile.py in read(filename, mmap)
#     231         mmap = False
#     232     else:
# --> 233         fid = open(filename, 'rb')
#     234
#     235     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/bigdata/scripts/development_set/anthonyschaller-20071221-\\wav\\a0491.wav'
