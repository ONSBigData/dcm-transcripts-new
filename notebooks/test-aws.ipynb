# %%
import sys
sys.path.insert(0, '/home/ons21553/wspace/interview-transcripts/src')
from common import *

# %load_ext autoreload
# %autoreload 2

# %%
from transcription.aws_trancribe import *

# %%
import recordings.recs as recs

# %%
from pydub import AudioSegment

# %%
r = recs.america_nepal.load()
r.audio_fpath
AudioSegment.from_mp3(r.audio_fpath)
# Out:
# '/home/ons21553/wspace/interview-transcripts/src/../data/recordings/america_nepal/audio.mp3'

# %%
transcript = transcribe(r.audio_fpath, language_code='en-US')
# Out:
# Using job name "transcribe-america_nepal__audio.mp3" and bucket fpath "america_nepal/audio.mp3"
# Uploading "/home/ons21553/wspace/interview-transcripts/src/../data/recordings/america_nepal/audio.mp3" to "america_nepal/audio.mp3" in "dcm-automatic-transcription" bucket
# Done
# Starting the transcription job transcribe-america_nepal__audio.mp3
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Done transcribing (151.93s)

# %%
transcript
# Out:
# {'jobName': 'transcribe-america_nepal__audio.mp3',
#  'accountId': '735156234108',
# ...
